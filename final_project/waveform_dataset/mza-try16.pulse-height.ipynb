# %%
# mostly pulled from hls4ml_3.ipynb and waveform_demo.ipynb
# https://fastmachinelearning.org/hls4ml/api/profiling.html
# last updated 2025-05-15 by mza
name = "mza_try16"
num_epochs = 10000
batch_size = 1000
truths_to_use = [ 2 ] # t_peak, t_sigma, height, pedestal
hidden_nodes = [ 14 ]; learning_rate = 0.1; hidden_node_type = "relu"
#hidden_nodes = [ 224 ]; learning_rate = 0.0825; hidden_node_type = "relu" # keras_tuner suggests: {'num_layers': 1, 'units_0': 224, 'activation': 'relu', 'lr': 0.08249331566936491}
model_reusefactor = 14 # Valid ReuseFactor(s): 1,2,4,7,8,14,16,28,32,56,112,224
input_qdense_reusefactor = 10000 # Valid ReuseFactor(s): 1,2,4,5,10,20,25,50,100,200,400,500,1000,2000,2500,5000,10000
hidden0qdense_reusefactor = 1400 # Valid ReuseFactor(s): 1,2,4,5,10,20,25,50,100,200,700,1400
use_pruning = False
prune_ratio = 0.1
train = True
synth_hls = True
# input quantization:
input_kernel_quantization = 7
input_kernel_integer_part = 0
input_bias_quantization = 9
input_bias_integer_part = 0
input_activation_quantization = 7
# hidden layer quantization:
inner_kernel_quantization = 7
inner_kernel_integer_part = 0
inner_bias_quantization = 9
inner_bias_integer_part = 0
inner_activation_quantization = 7
# output quantization:
output_kernel_quantization = 6
output_kernel_integer_part = 3
output_bias_quantization = 8
output_bias_integer_part = 0
output_cartoon_quantization = 6
output_cartoon_integer_part = 3
default_quantization = 6
default_integer_part = 3
csim = False
cosim = False

# %%
import os, errno
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ['PATH'] = os.environ['XILINX_VIVADO'] + '/bin:' + os.environ['PATH']
import numpy as np
seed = 0
np.random.seed(seed)
import matplotlib.pyplot as plt
try:
    os.mkdir(name)
except OSError as exception:
    if exception.errno != errno.EEXIST:
        raise
import tensorflow as tf
tf.random.set_seed(seed)
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l1
from tensorflow.keras.layers import Activation
from tensorflow.keras import optimizers
from callbacks import all_callbacks
from qkeras.qlayers import QDense, QActivation
from qkeras.quantizers import quantized_bits, quantized_relu, quantized_sigmoid

# %%
dataset1 = np.load('waveform_data_0.npy') # (10000, 104)
dataset2 = np.load('waveform_data_1.npy') # (10000, 104)
dataset = np.concatenate((dataset1, dataset2))
num_waveforms = len(dataset)
training_quantity = int(0.8 * num_waveforms)
num_truths = 4
time_samples = len(dataset[0]) - num_truths
#print("num_waveforms: " + str(num_waveforms))
num_truths_to_use = len(truths_to_use)
#print("num_truths_to_use: " + str(num_truths_to_use))
waveforms = dataset[:,num_truths:]
truths = dataset[:,:num_truths]
waveform_min = min([ min(waveforms[i]) for i in range(len(waveforms)) ])
waveform_max = max([ max(waveforms[i]) for i in range(len(waveforms)) ])
offset = waveform_min
gain = 1.0 / (waveform_max - waveform_min)
scaled_waveforms = np.array([ [ gain * (waveforms[j,i] - offset) for i in range(time_samples) ] for j in range(num_waveforms) ])
scaled_truths = np.array([ [ truths[j,0]/time_samples, truths[j,1]/time_samples, gain * (truths[j,2] - offset), gain * (truths[j,3] - offset) ] for j in range(num_waveforms) ])
train_data = scaled_waveforms[:training_quantity,:]
#print("train_data.shape: " + str(train_data.shape))
train_truth = scaled_truths[:training_quantity,truths_to_use]
#print("train_truth.shape: " + str(train_truth.shape))
test_data = scaled_waveforms[training_quantity:,:]
#print("test_data.shape: " + str(test_data.shape))
test_truth = scaled_truths[training_quantity:,truths_to_use]
#print("test_truth.shape: " + str(test_truth.shape))

# %%
evt = 8
if 0:
    x = np.zeros(time_samples)
    for i in range(time_samples):
        x[i] = i/time_samples
    y = train_data[evt]
    plt.xlim(0, 1), plt.ylim(0, 1)
    plt.scatter(x, y)
    plt.plot([0.0, 1.0], [scaled_truths[evt][3] + scaled_truths[evt][2], scaled_truths[evt][3] + scaled_truths[evt][2]], color="green")
    plt.show()

# %%
input_kernel_quantizer = quantized_bits(bits=input_kernel_quantization, integer=input_kernel_integer_part, alpha=1)
input_bias_quantizer = quantized_bits(bits=input_bias_quantization, integer=input_bias_integer_part, alpha=1)
inner_kernel_quantizer = quantized_bits(bits=inner_kernel_quantization, integer=inner_kernel_integer_part, alpha=1)
inner_bias_quantizer = quantized_bits(bits=inner_bias_quantization, integer=inner_bias_integer_part, alpha=1)
output_kernel_quantizer = quantized_bits(bits=output_kernel_quantization, integer=output_kernel_integer_part, alpha=1)
output_bias_quantizer = quantized_bits(bits=output_bias_quantization, integer=output_bias_integer_part, alpha=1)
Q = "RND_CONV"; O = "SAT"; N = "0"
default_quantization_string = 'ap_fixed<' + str(default_quantization) + ',' + str(default_integer_part) + ',' + Q + ',' + O + ',' + N + '>'
output_quantization_string = 'ap_fixed<' + str(output_cartoon_quantization) + ',' + str(output_cartoon_integer_part) + ',' + Q + ',' + O + ',' + N + '>'
if hidden_node_type=="relu":
    hidden_activations = [ quantized_relu(bits=inner_activation_quantization) for i in range(len(hidden_nodes)) ]
else:
    hidden_activations = [ quantized_sigmoid(bits=inner_activation_quantization) for i in range(len(hidden_nodes)) ]
hidden_names = [ hidden_node_type for i in range(len(hidden_nodes)) ]
model = Sequential()
model.add(QDense(units=time_samples, input_shape=(time_samples,), name='input_qdense', kernel_quantizer=input_kernel_quantizer, bias_quantizer=input_bias_quantizer, kernel_initializer='glorot_uniform'))
model.add(QActivation(activation=quantized_sigmoid(bits=input_activation_quantization), name='input_sigmoid'))
for i in range(len(hidden_nodes)):
    model.add(QDense(units=hidden_nodes[i], name=hidden_names[i] + str(i) + "qdense", kernel_quantizer=inner_kernel_quantizer, bias_quantizer=inner_bias_quantizer, kernel_initializer='glorot_uniform'))
    model.add(QActivation(activation=hidden_activations[i], name=hidden_names[i] + str(i) + "activation"))
model.add(QDense(units=num_truths_to_use, name='output_qdense', kernel_quantizer=output_kernel_quantizer, bias_quantizer=output_bias_quantizer, kernel_initializer='glorot_uniform'))
if num_truths_to_use<2:
    model.add(Activation(activation='sigmoid', name='output_sigmoid'))
    output_layer_name = 'output_sigmoid'
else:
    model.add(Activation(activation='softmax', name='output_softmax'))
    output_layer_name = 'output_softmax'

# %%
import callbacks # https://keras.io/guides/writing_your_own_callbacks/
class CustomCallback(callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        if epoch%1000==0:
            print("epoch: " + str(epoch) + "/" + str(num_epochs))
        if epoch==num_epochs-1:
            print("epoch: " + str(epoch) + "/" + str(num_epochs))

# %%
if use_pruning:
    from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
    from tensorflow_model_optimization.sparsity.keras import strip_pruning
    # the first argument is the percentage of the weights that will be forced to be 0
    pruning_params = {"pruning_schedule": pruning_schedule.ConstantSparsity(prune_ratio, begin_step=2000, frequency=100)}
    model = prune.prune_low_magnitude(model, **pruning_params)

# %%
if train:
    #optimizer = optimizers.Adam(learning_rate=learning_rate)
    optimizer = optimizers.SGD(learning_rate=learning_rate)
    #model.compile(optimizer=optimizer, loss=['categorical_crossentropy'], metrics=['accuracy'])
    model.compile(optimizer=optimizer, loss=['mse'])
    if use_pruning:
        callbacks = all_callbacks(stop_patience=1000, lr_factor=0.5, lr_patience=10, lr_epsilon=0.000001, lr_cooldown=2, lr_minimum=0.0000001, outputDir=name)
        callbacks.callbacks.append(pruning_callbacks.UpdatePruningStep())
        model.fit(train_data, train_truth, batch_size=batch_size, epochs=num_epochs, validation_split=0.25, shuffle=False, callbacks=callbacks.callbacks, verbose=0)
    else:
        model.fit(train_data, train_truth, batch_size=batch_size, epochs=num_epochs, validation_split=0.25, shuffle=False, verbose=0, callbacks=[CustomCallback()])
    #loss, acc = model.evaluate(test_data, test_truth, verbose=0)
    if use_pruning:
        model = strip_pruning(model)
    model.save(name + '/KERAS_check_best_model.keras')
else:
    from tensorflow.keras.models import load_model
    from qkeras.utils import _add_supported_quantized_objects
    co = {}
    _add_supported_quantized_objects(co)
    model = load_model(name + '/KERAS_check_best_model.keras', custom_objects=co) # TypeError: <qkeras.qlayers.QActivation object at 0x774300567100> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
# Out:
# epoch: 0/10000
# epoch: 1000/10000
# epoch: 2000/10000
# epoch: 3000/10000
# epoch: 4000/10000
# epoch: 5000/10000
# epoch: 6000/10000
# epoch: 7000/10000
# epoch: 8000/10000
# epoch: 9000/10000
# epoch: 9999/10000
# /root/anaconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/keras/src/constraints.py:365: UserWarning: The `keras.constraints.serialize()` API should only be used for objects of type `keras.constraints.Constraint`. Found an instance of type <class 'qkeras.quantizers.quantized_bits'>, which may lead to improper serialization.
#   warnings.warn(

# %%
#print('test_acc: {:.3f}, test_loss: {:.3f}'.format(acc, loss))
train_prediction = model.predict(train_data)
test_prediction = model.predict(test_data)
# Out:
# 500/500 [==============================] - 1s 658us/step
# 125/125 [==============================] - 0s 652us/step

# %%
evt = 6
if 0:
    x = np.zeros(time_samples)
    for i in range(time_samples):
        x[i] = i/time_samples
    y = train_data[evt]
    plt.xlim(0, 1), plt.ylim(0, 1)
    plt.scatter(x, y, color="blue")
    plt.plot([0.0, 1.0], [scaled_truths[evt][3] + scaled_truths[evt][2], scaled_truths[evt][3] + scaled_truths[evt][2]], color="green")
    plt.plot([0.0, 1.0], [scaled_truths[evt][3] + train_prediction[evt][0], scaled_truths[evt][3] + train_prediction[evt][0]], color="red")
    plt.show()

# %%
if 1:
    import csv
    with open(name + '/Input.dat', 'w') as f:
        csv.writer(f, delimiter=' ').writerows(test_data)
    with open(name + '/Output.dat', 'w') as f:
        csv.writer(f, delimiter=' ').writerows(test_prediction)

# %%
import hls4ml, plotting
config = hls4ml.utils.config_from_keras_model(model, granularity='name')
config['LayerName'][output_layer_name]['exp_table_t'] = output_quantization_string
config['LayerName'][output_layer_name]['inv_table_t'] = output_quantization_string
config['LayerName'][output_layer_name]['Precision']   = output_quantization_string
config['IOType'] = 'io_stream' # io_parallel/io_stream
config['Model']['Precision']['default'] = default_quantization_string
config['Model']['Strategy'] = 'Resource'
config['Model']['ReuseFactor'] = model_reusefactor
config['LayerName']['input_qdense']['ReuseFactor'] = input_qdense_reusefactor
config['LayerName'][hidden_names[0] + "0qdense"]['ReuseFactor'] = hidden0qdense_reusefactor
config['Model']['TraceOutput'] = True
for layer in config['LayerName'].keys():
    config['LayerName'][layer]['Trace'] = True
    config['LayerName'][layer]['Strategy'] = 'Resource'
plotting.print_dict(config)
hls_model = hls4ml.converters.convert_from_keras_model(
    model, hls_config=config, output_dir=name + '/hls4ml_prj', part='xc7z020clg400-1',
    input_data_tb = name + "/Input.dat", output_data_tb = name + "/Output.dat", backend='Vitis', verbose=0)
# Out:
# Interpreting Sequential
# Topology:
# Layer name: input_qdense_input, layer type: InputLayer, input shapes: [[None, 100]], output shape: [None, 100]
# Layer name: input_qdense, layer type: QDense, input shapes: [[None, 100]], output shape: [None, 100]
# Layer name: input_sigmoid, layer type: HardActivation, input shapes: [[None, 100]], output shape: [None, 100]
# Layer name: relu0qdense, layer type: QDense, input shapes: [[None, 100]], output shape: [None, 14]
# Layer name: relu0activation, layer type: Activation, input shapes: [[None, 14]], output shape: [None, 14]
# Layer name: output_qdense, layer type: QDense, input shapes: [[None, 14]], output shape: [None, 1]
# Layer name: output_sigmoid, layer type: Activation, input shapes: [[None, 1]], output shape: [None, 1]
# Model
#   Precision
#     default:         ap_fixed<6,3,RND_CONV,SAT,0>
#   ReuseFactor:       14
#   Strategy:          Resource
#   BramFactor:        1000000000
#   TraceOutput:       True
# LayerName
#   input_qdense_input
#     Trace:           True
#     Precision
#       result:        auto
#     Strategy:        Resource
#   input_qdense
#     Trace:           True
#     Precision
#       result:        auto
#       weight:        fixed<7,1,TRN,WRAP,0>
#       bias:          fixed<9,1,TRN,WRAP,0>
#     ReuseFactor:     10000
#     Strategy:        Resource
#   input_qdense_linear
#     Trace:           True
#     Precision
#       result:        auto
#     Strategy:        Resource
#   input_sigmoid
#     Trace:           True
#     Precision
#       result:        ufixed<7,0,RND_CONV,SAT,0>
#       slope:         auto
#       shift:         auto
#     Strategy:        Resource
#   relu0qdense
#     Trace:           True
#     Precision
#       result:        auto
#       weight:        fixed<7,1,TRN,WRAP,0>
#       bias:          fixed<9,1,TRN,WRAP,0>
#     ReuseFactor:     1400
#     Strategy:        Resource
#   relu0qdense_linear
#     Trace:           True
#     Precision
#       result:        auto
#     Strategy:        Resource
#   relu0activation
#     Trace:           True
#     Precision
#       result:        ufixed<7,0,RND_CONV,SAT,0>
#     Strategy:        Resource
#   output_qdense
#     Trace:           True
#     Precision
#       result:        auto
#       weight:        fixed<6,4,TRN,WRAP,0>
#       bias:          fixed<8,1,TRN,WRAP,0>
#     Strategy:        Resource
#   output_qdense_linear
#     Trace:           True
#     Precision
#       result:        auto
#     Strategy:        Resource
#   output_sigmoid
#     Trace:           True
#     Precision:       ap_fixed<6,3,RND_CONV,SAT,0>
#     exp_table_t:     ap_fixed<6,3,RND_CONV,SAT,0>
#     inv_table_t:     ap_fixed<6,3,RND_CONV,SAT,0>
#     Strategy:        Resource
# IOType:              io_stream
# Interpreting Sequential
# Topology:
# Layer name: input_qdense_input, layer type: InputLayer, input shapes: [[None, 100]], output shape: [None, 100]
# Layer name: input_qdense, layer type: QDense, input shapes: [[None, 100]], output shape: [None, 100]
# Layer name: input_sigmoid, layer type: HardActivation, input shapes: [[None, 100]], output shape: [None, 100]
# Layer name: relu0qdense, layer type: QDense, input shapes: [[None, 100]], output shape: [None, 14]
# Layer name: relu0activation, layer type: Activation, input shapes: [[None, 14]], output shape: [None, 14]
# Layer name: output_qdense, layer type: QDense, input shapes: [[None, 14]], output shape: [None, 1]
# Layer name: output_sigmoid, layer type: Activation, input shapes: [[None, 1]], output shape: [None, 1]
# Creating HLS model
# /root/anaconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/keras/src/constraints.py:365: UserWarning: The `keras.constraints.serialize()` API should only be used for objects of type `keras.constraints.Constraint`. Found an instance of type <class 'qkeras.quantizers.quantized_bits'>, which may lead to improper serialization.
#   warnings.warn(

# %%
from IPython.display import Image
hls4ml.utils.plot_model(hls_model, show_shapes=True, show_precision=True, to_file=name + '/hls_model.png')
Image(name + '/hls_model.png')

# %%
hls_model.compile()
# Out:
# /root/anaconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/keras/src/constraints.py:365: UserWarning: The `keras.constraints.serialize()` API should only be used for objects of type `keras.constraints.Constraint`. Found an instance of type <class 'qkeras.quantizers.quantized_bits'>, which may lead to improper serialization.
#   warnings.warn(
# Writing HLS project
# Done

# %%
hls_train_prediction = hls_model.predict(np.ascontiguousarray(train_data))
hls_test_prediction = hls_model.predict(np.ascontiguousarray(test_data))

# %%
nbins = 100
a = 0.07; b = 0.58
for i in range(num_truths_to_use):
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(12,12))
    ax1.hist2d(train_truth[:,i].ravel(), train_prediction[:,i].ravel(),     bins=nbins); ax1.plot([0.0, 1.0], [0.0, 1.0], color="red", alpha=0.5); ax1.set_xlim(a, b); ax1.set_ylim(a, b)
    ax2.hist2d(test_truth[:,i].ravel(),  test_prediction[:,i].ravel(),      bins=nbins); ax2.plot([0.0, 1.0], [0.0, 1.0], color="red", alpha=0.5); ax2.set_xlim(a, b); ax2.set_ylim(a, b)
    ax3.hist2d(train_truth[:,i].ravel(), hls_train_prediction[:,i].ravel(), bins=nbins); ax3.plot([0.0, 1.0], [0.0, 1.0], color="red", alpha=0.5); ax3.set_xlim(a, b); ax3.set_ylim(a, b)
    ax4.hist2d(test_truth[:,i].ravel(),  hls_test_prediction[:,i].ravel(),  bins=nbins); ax4.plot([0.0, 1.0], [0.0, 1.0], color="red", alpha=0.5); ax4.set_xlim(a, b); ax4.set_ylim(a, b)
    plt.show()
    fig.savefig(name + "/hist2d." + str(truths_to_use[i]) + ".png")

# %%
from hls4ml.model.profiling import numerical
plots = numerical(model=model, hls_model=hls_model, X=np.ascontiguousarray(train_data))
plt.show()
# Out:
# /root/anaconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/keras/src/constraints.py:365: UserWarning: The `keras.constraints.serialize()` API should only be used for objects of type `keras.constraints.Constraint`. Found an instance of type <class 'qkeras.quantizers.quantized_bits'>, which may lead to improper serialization.
#   warnings.warn(
# Interpreting Sequential
# Topology:
# Layer name: input_qdense_input, layer type: InputLayer, input shapes: [[None, 100]], output shape: [None, 100]
# Layer name: input_qdense, layer type: QDense, input shapes: [[None, 100]], output shape: [None, 100]
# Layer name: input_sigmoid, layer type: HardActivation, input shapes: [[None, 100]], output shape: [None, 100]
# Layer name: relu0qdense, layer type: QDense, input shapes: [[None, 100]], output shape: [None, 14]
# Layer name: relu0activation, layer type: Activation, input shapes: [[None, 14]], output shape: [None, 14]
# Layer name: output_qdense, layer type: QDense, input shapes: [[None, 14]], output shape: [None, 1]
# Layer name: output_sigmoid, layer type: Activation, input shapes: [[None, 1]], output shape: [None, 1]
# Creating HLS model
# Profiling weights (before optimization)
# Profiling weights (final / after optimization)
# Profiling activations (before optimization)
# 500/500 [==============================] - 1s 839us/step
#    input_qdense
#    input_sigmoid
#    relu0qdense
#    relu0activation
#    output_qdense
#    output_sigmoid
# Profiling activations (final / after optimization)
# Recompiling myproject with tracing
# Writing HLS project
# Done
# /root/anaconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/keras/src/constraints.py:365: UserWarning: The `keras.constraints.serialize()` API should only be used for objects of type `keras.constraints.Constraint`. Found an instance of type <class 'qkeras.quantizers.quantized_bits'>, which may lead to improper serialization.
#   warnings.warn(
#    input_qdense
#    input_sigmoid
#    relu0qdense
#    relu0activation
#    output_qdense
#    output_sigmoid

# %%
if synth_hls:
    hls_model.build(synth=True, csim=csim, cosim=cosim)
# Out:
# ****** Vitis HLS - High-Level Synthesis from C, C++ and OpenCL v2023.1 (64-bit)
#   **** SW Build 3854077 on May  4 2023
#   **** IP Build 3864474 on Sun May  7 20:36:21 MDT 2023
#   **** SharedData Build 3865790 on Sun May 07 13:33:03 MDT 2023
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2023 Advanced Micro Devices, Inc. All Rights Reserved.
#
# source /opt/Xilinx/Vitis_HLS/2023.1/scripts/vitis_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/opt/Xilinx/Vitis_HLS/2023.1/bin/unwrapped/lnx64.o/vitis_hls'
# INFO: [HLS 200-10] For user 'root' on host 'c1a90f3b3abf' (Linux_x86_64 version 6.11.0-21-generic) on Thu May 15 20:58:38 EDT 2025
# INFO: [HLS 200-10] In directory '/root/build/phys476/final_project/waveform_dataset/mza_try16/hls4ml_prj'
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-1510] Running: open_project myproject_prj
# INFO: [HLS 200-10] Opening project '/root/build/phys476/final_project/waveform_dataset/mza_try16/hls4ml_prj/myproject_prj'.
# INFO: [HLS 200-1510] Running: set_top myproject
# INFO: [HLS 200-1510] Running: add_files firmware/myproject.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb myproject_test.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb firmware/weights
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-1510] Running: add_files -tb tb_data
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-1510] Running: open_solution solution1
# INFO: [HLS 200-10] Opening solution '/root/build/phys476/final_project/waveform_dataset/mza_try16/hls4ml_prj/myproject_prj/solution1'.
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 5ns.
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 1.35ns.
# INFO: [HLS 200-1611] Setting target device to 'xc7z020-clg400-1'
# INFO: [HLS 200-1505] Using flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=200-1505.html
# INFO: [HLS 200-1464] Running solution command: config_compile -name_max_length=80
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1464] Running solution command: config_compile -complex-mul-dsp=0
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1464] Running solution command: config_schedule -enable_dsp_full_reg=0
# INFO: [HLS 200-1510] Running: config_array_partition -maximum_size 4096
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# ERROR: [HLS 200-642] The 'config_array_partition -maximum_size' command is not supported.
# INFO: [HLS 200-1510] Running: config_compile -name_max_length 80
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: set_part xc7z020clg400-1
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: config_schedule -enable_dsp_full_reg=false
# INFO: [HLS 200-1510] Running: create_clock -period 5 -name default
# INFO: [HLS 200-1510] Running: set_clock_uncertainty 27% default
# ***** C/RTL SYNTHESIS *****
# INFO: [HLS 200-1510] Running: csynth_design
# INFO: [HLS 200-111] Finished File checks and directory preparation: CPU user time: 0.06 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.07 seconds; current allocated memory: 1.065 GB.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 207-5531] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:33:9)
# WARNING: [HLS 207-5531] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:107:9)
# WARNING: [HLS 207-5531] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:189:9)
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:38:87)
# Resolution: For help on HLS 214-113 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:38:91)
# Resolution: For help on HLS 214-113 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:52:79)
# Resolution: For help on HLS 214-113 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:52:83)
# Resolution: For help on HLS 214-113 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:66:81)
# Resolution: For help on HLS 214-113 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:66:85)
# Resolution: For help on HLS 214-113 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=214-113.html
# WARNING: [HLS 200-471] Dataflow form checks found 6 issue(s) in file firmware/myproject.cpp
# Resolution: For help on HLS 200-471 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=200-471.html
# WARNING: [HLS 207-5292] unused parameter 'keep' (firmware/nnet_utils/nnet_helpers.h:285:99)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:14:36)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (firmware/nnet_utils/nnet_function_stubs.h:15:36)
# WARNING: [HLS 207-5292] unused parameter 'partition' (firmware/nnet_utils/nnet_function_stubs.h:16:44)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:24:24)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (firmware/nnet_utils/nnet_function_stubs.h:25:24)
# WARNING: [HLS 207-5292] unused parameter 'partition' (firmware/nnet_utils/nnet_function_stubs.h:26:32)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:33:30)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:33:58)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:34:51)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:35:49)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:42:30)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:42:58)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:43:51)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:44:49)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:51:29)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:51:80)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:52:50)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:53:48)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_code_gen.h:16:39)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_code_gen.h:17:38)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_code_gen.h:18:60)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_code_gen.h:19:58)
# INFO: [HLS 200-111] Finished Source Code Analysis and Preprocessing: CPU user time: 8.85 seconds. CPU system time: 0.64 seconds. Elapsed time: 9.49 seconds; current allocated memory: 1.069 GB.
# INFO: [HLS 200-777] Using interface defaults for 'Vivado' flow target.
# INFO: [HLS 200-1995] There were 6,244 instructions in the design after the 'Compile/Link' phase of compilation. See the Design Size Report for more details: /root/build/phys476/final_project/waveform_dataset/mza_try16/hls4ml_prj/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 17,998 instructions in the design after the 'Unroll/Inline' phase of compilation. See the Design Size Report for more details: /root/build/phys476/final_project/waveform_dataset/mza_try16/hls4ml_prj/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 8,409 instructions in the design after the 'Performance/Pipeline' phase of compilation. See the Design Size Report for more details: /root/build/phys476/final_project/waveform_dataset/mza_try16/hls4ml_prj/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 7,845 instructions in the design after the 'Optimizations' phase of compilation. See the Design Size Report for more details: /root/build/phys476/final_project/waveform_dataset/mza_try16/hls4ml_prj/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# WARNING: [HLS 214-273] In function 'void nnet::dense<ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*)', Pragma conflict happens on 'INLINE' and DATAFLOW pragmas: Inline into dataflow region may break the canonical form (firmware/nnet_utils/nnet_dense.h:43:0)
# WARNING: [HLS 214-273] In function 'void nnet::dense<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>*, config5::weight_t*, config5::bias_t*)', Pragma conflict happens on 'INLINE' and DATAFLOW pragmas: Inline into dataflow region may break the canonical form (firmware/nnet_utils/nnet_dense.h:43:0)
# WARNING: [HLS 214-273] In function 'void nnet::dense<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>*, config8::weight_t*, config8::bias_t*)', Pragma conflict happens on 'INLINE' and DATAFLOW pragmas: Inline into dataflow region may break the canonical form (firmware/nnet_utils/nnet_dense.h:43:0)
# WARNING: [HLS 214-273] In function 'nnet::DenseResource_rf_leq_nin<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>::dense(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<6, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>*)', Pragma conflict happens on 'INLINE' and DATAFLOW pragmas: Inline into dataflow region may break the canonical form (firmware/nnet_utils/nnet_dense.h:63:0)
# WARNING: [HLS 214-273] In function 'nnet::DenseResource_rf_gt_nin_rem0<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>::dense(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<7, 1, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<9, 1, (ap_q_mode)5, (ap_o_mode)3, 0>*)', Pragma conflict happens on 'INLINE' and DATAFLOW pragmas: Inline into dataflow region may break the canonical form (firmware/nnet_utils/nnet_dense.h:74:0)
# WARNING: [HLS 214-273] In function 'nnet::DenseResource_rf_gt_nin_rem0<ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>::dense(ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<7, 1, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<9, 1, (ap_q_mode)5, (ap_o_mode)3, 0>*)', Pragma conflict happens on 'INLINE' and DATAFLOW pragmas: Inline into dataflow region may break the canonical form (firmware/nnet_utils/nnet_dense.h:74:0)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<7, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<7, 1, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_dense_resource.h:145:17)
# INFO: [HLS 214-131] Inlining function 'nnet::DenseResource_rf_gt_nin_rem0<ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>::dense(ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<7, 1, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<9, 1, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'void nnet::dense<ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_dense.h:45:2)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<7, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<7, 1, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>*, config5::weight_t*, config5::bias_t*)' (firmware/nnet_utils/nnet_dense_resource.h:145:17)
# INFO: [HLS 214-131] Inlining function 'nnet::DenseResource_rf_gt_nin_rem0<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>::dense(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<7, 1, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<9, 1, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'void nnet::dense<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>*, config5::weight_t*, config5::bias_t*)' (firmware/nnet_utils/nnet_dense.h:45:2)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<6, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<6, 4, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_resource_rf_leq_nin<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>*, config8::weight_t*, config8::bias_t*)' (firmware/nnet_utils/nnet_dense_resource.h:59:17)
# INFO: [HLS 214-131] Inlining function 'nnet::DenseResource_rf_leq_nin<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>::dense(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<6, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'void nnet::dense<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>*, config8::weight_t*, config8::bias_t*)' (firmware/nnet_utils/nnet_dense.h:45:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::dense<ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*)' into 'myproject(ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>*)' (firmware/myproject.cpp:38:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::dense<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>*, config5::weight_t*, config5::bias_t*)' into 'myproject(ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>*)' (firmware/myproject.cpp:52:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::dense<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>*, config8::weight_t*, config8::bias_t*)' into 'myproject(ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>*)' (firmware/myproject.cpp:66:2)
# INFO: [HLS 214-291] Loop 'VITIS_LOOP_114_1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation.h:114:23)
# INFO: [HLS 214-291] Loop 'MultLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_resource.h:55:9)
# INFO: [HLS 214-291] Loop 'VITIS_LOOP_43_1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation.h:43:22)
# INFO: [HLS 214-291] Loop 'MultLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_resource.h:142:9)
# INFO: [HLS 214-291] Loop 'VITIS_LOOP_473_1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation.h:473:20)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_114_1' (firmware/nnet_utils/nnet_activation.h:114:23) in function 'nnet::sigmoid<ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, sigmoid_config10>' completely with a factor of 1 (firmware/nnet_utils/nnet_activation.h:95:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:80:5) in function 'nnet::dense_resource_rf_leq_nin<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_resource.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:55:9) in function 'nnet::dense_resource_rf_leq_nin<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_resource.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:40:5) in function 'nnet::dense_resource_rf_leq_nin<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_resource.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_43_1' (firmware/nnet_utils/nnet_activation.h:43:22) in function 'nnet::relu<ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, relu_config7>' completely with a factor of 14 (firmware/nnet_utils/nnet_activation.h:39:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:162:5) in function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 14 (firmware/nnet_utils/nnet_dense_resource.h:89:0)
# INFO: [HLS 214-186] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:142:9) in function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_resource.h:89:0)
# INFO: [HLS 214-186] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:114:5) in function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 14 (firmware/nnet_utils/nnet_dense_resource.h:89:0)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_473_1' (firmware/nnet_utils/nnet_activation.h:473:20) in function 'nnet::hard_sigmoid<ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, hard_sigmoid_config4>' completely with a factor of 100 (firmware/nnet_utils/nnet_activation.h:470:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:162:5) in function 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 100 (firmware/nnet_utils/nnet_dense_resource.h:89:0)
# INFO: [HLS 214-186] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:142:9) in function 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_resource.h:89:0)
# INFO: [HLS 214-186] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:114:5) in function 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 100 (firmware/nnet_utils/nnet_dense_resource.h:89:0)
# INFO: [HLS 214-178] Inlining function 'std::enable_if<!(std::is_same<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_uint<1> >::value), ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0> >::type nnet::cast<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(config5::accum_t)' into 'void nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>*, config5::weight_t*, config5::bias_t*)' (firmware/nnet_utils/nnet_dense_resource.h:89:0)
# INFO: [HLS 214-178] Inlining function 'std::enable_if<!(std::is_same<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_uint<1> >::value), ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0> >::type nnet::cast<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>(config8::accum_t)' into 'void nnet::dense_resource_rf_leq_nin<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>(ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>*, config8::weight_t*, config8::bias_t*)' (firmware/nnet_utils/nnet_dense_resource.h:15:0)
# INFO: [HLS 214-248] Applying array_partition to 'b8': Complete partitioning on dimension 1. (firmware/weights/b8.h:12:0)
# INFO: [HLS 214-248] Applying array_partition to 'b5': Complete partitioning on dimension 1. (firmware/weights/b5.h:12:0)
# INFO: [HLS 214-248] Applying array_partition to 'b2': Complete partitioning on dimension 1. (firmware/weights/b2.h:12:0)
# INFO: [HLS 214-248] Applying array_partition to 'acc': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_dense_resource.h:110:32)
# INFO: [HLS 214-248] Applying array_partition to 'layer2_out': Complete partitioning on dimension 1. (firmware/myproject.cpp:36:24)
# INFO: [HLS 214-248] Applying array_partition to 'layer4_out': Complete partitioning on dimension 1. (firmware/myproject.cpp:43:14)
# INFO: [HLS 214-248] Applying array_partition to 'layer5_out': Complete partitioning on dimension 1. (firmware/myproject.cpp:50:26)
# INFO: [HLS 214-248] Applying array_partition to 'layer7_out': Complete partitioning on dimension 1. (firmware/myproject.cpp:57:14)
# INFO: [HLS 214-248] Applying array_partition to 'layer8_out': Complete partitioning on dimension 1. (firmware/myproject.cpp:64:28)
# INFO: [HLS 214-248] Applying array_partition to 'layer10_out': Complete partitioning on dimension 1. (firmware/myproject.cpp:10:0)
# INFO: [HLS 214-248] Applying array_reshape to 'input_qdense_input': Complete reshaping on dimension 1. (firmware/myproject.cpp:10:0)
# INFO: [HLS 200-111] Finished Compiling Optimization and Transform: CPU user time: 9.32 seconds. CPU system time: 0.97 seconds. Elapsed time: 12.61 seconds; current allocated memory: 1.070 GB.
# INFO: [HLS 200-111] Finished Checking Pragmas: CPU user time: 0 seconds. CPU system time: 0 seconds. Elapsed time: 0 seconds; current allocated memory: 1.070 GB.
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [HLS 200-111] Finished Standard Transforms: CPU user time: 0.3 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.32 seconds; current allocated memory: 1.080 GB.
# INFO: [HLS 200-10] Checking synthesizability ...
# WARNING: [SYNCHK 200-23] firmware/nnet_utils/nnet_dense_resource.h:135: variable-indexed range selection may cause suboptimal QoR.
# INFO: [SYNCHK 200-10] 0 error(s), 1 warning(s).
# INFO: [HLS 200-111] Finished Checking Synthesizability: CPU user time: 0.31 seconds. CPU system time: 0 seconds. Elapsed time: 0.31 seconds; current allocated memory: 1.087 GB.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_resource.h:164) automatically.
# INFO: [XFORM 203-712] Applying dataflow to function 'myproject' (firmware/myproject.cpp:36:1), detected/extracted 6 process function(s):
# 	 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>'
# 	 'nnet::hard_sigmoid<ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, hard_sigmoid_config4>'
# 	 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>'
# 	 'nnet::relu<ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, relu_config7>'
# 	 'nnet::dense_resource_rf_leq_nin<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>'
# 	 'nnet::sigmoid<ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, sigmoid_config10>'.
# INFO: [XFORM 203-401] Performing if-conversion on hyperblock from (firmware/nnet_utils/nnet_activation.h:109:9) to (firmware/nnet_utils/nnet_activation.h:123:1) in function 'nnet::sigmoid<ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, sigmoid_config10>'... converting 3 basic blocks.
# INFO: [XFORM 203-401] Performing if-conversion on hyperblock from (firmware/nnet_utils/nnet_activation.h:40:9) to (firmware/nnet_utils/nnet_activation.h:50:1) in function 'nnet::relu<ap_fixed<22, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, relu_config7>'... converting 57 basic blocks.
# INFO: [XFORM 203-401] Performing if-conversion on hyperblock from (firmware/nnet_utils/nnet_activation.h:471:9) to (firmware/nnet_utils/nnet_activation.h:481:1) in function 'nnet::hard_sigmoid<ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, hard_sigmoid_config4>'... converting 201 basic blocks.
# INFO: [XFORM 203-401] Performing if-conversion on hyperblock from (firmware/nnet_utils/nnet_dense_resource.h:47:9) to (firmware/nnet_utils/nnet_dense_resource.h:46:5) in function 'nnet::dense_resource_rf_leq_nin<ap_ufixed<7, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 9, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>'... converting 3 basic blocks.
# INFO: [XFORM 203-401] Performing if-conversion on hyperblock from (firmware/nnet_utils/nnet_dense_resource.h:136:9) to (firmware/nnet_utils/nnet_dense_resource.h:144:17) in function 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<6, 3, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<21, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>'... converting 3 basic blocks.
# INFO: [HLS 200-111] Finished Loop, function and other optimizations: CPU user time: 2.01 seconds. CPU system time: 0.01 seconds. Elapsed time: 2.02 seconds; current allocated memory: 1.126 GB.
# INFO: [XFORM 203-531] Rewinding loop 'ReuseLoop' (firmware/nnet_utils/nnet_dense_resource.h:46) in function 'dense_resource_rf_leq_nin<ap_ufixed,ap_fixed<18,9,5,3,0>,config8>'.
# INFO: [XFORM 203-531] Rewinding loop 'ReuseLoop' (firmware/nnet_utils/nnet_dense_resource.h:135) in function 'dense_resource_rf_gt_nin_rem0<ap_ufixed,ap_fixed<22,9,5,3,0>,config5>'.
# INFO: [XFORM 203-531] Rewinding loop 'ReuseLoop' (firmware/nnet_utils/nnet_dense_resource.h:135) in function 'dense_resource_rf_gt_nin_rem0<ap_fixed,ap_fixed<21,12,5,3,0>,config2>'.
# INFO: [HLS 200-111] Finished Architecture Synthesis: CPU user time: 2.07 seconds. CPU system time: 0.04 seconds. Elapsed time: 2.11 seconds; current allocated memory: 1.270 GB.
# INFO: [HLS 200-10] Starting hardware synthesis ...
# INFO: [HLS 200-10] Synthesizing 'myproject' ...
# WARNING: [SYN 201-103] Legalizing function name 'dense_resource_rf_gt_nin_rem0<ap_fixed,ap_fixed<21,12,5,3,0>,config2>' to 'dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s'.
# WARNING: [SYN 201-103] Legalizing function name 'hard_sigmoid<ap_fixed,ap_ufixed<7,0,4,0,0>,hard_sigmoid_config4>' to 'hard_sigmoid_ap_fixed_ap_ufixed_7_0_4_0_0_hard_sigmoid_config4_s'.
# WARNING: [SYN 201-103] Legalizing function name 'dense_resource_rf_gt_nin_rem0<ap_ufixed,ap_fixed<22,9,5,3,0>,config5>' to 'dense_resource_rf_gt_nin_rem0_ap_ufixed_ap_fixed_22_9_5_3_0_config5_s'.
# WARNING: [SYN 201-103] Legalizing function name 'relu<ap_fixed<22, 9, 5, 3, 0>, ap_ufixed<7, 0, 4, 0, 0>, relu_config7>' to 'relu_ap_fixed_22_9_5_3_0_ap_ufixed_7_0_4_0_0_relu_config7_s'.
# WARNING: [SYN 201-103] Legalizing function name 'dense_resource_rf_leq_nin<ap_ufixed,ap_fixed<18,9,5,3,0>,config8>' to 'dense_resource_rf_leq_nin_ap_ufixed_ap_fixed_18_9_5_3_0_config8_s'.
# WARNING: [SYN 201-103] Legalizing function name 'sigmoid<ap_fixed<18, 9, 5, 3, 0>, ap_fixed<6, 3, 4, 0, 0>, sigmoid_config10>' to 'sigmoid_ap_fixed_18_9_5_3_0_ap_fixed_6_3_4_0_0_sigmoid_config10_s'.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining loop 'ReuseLoop'.
# INFO: [HLS 200-1470] Pipelining result : Target II = 1, Final II = 1, Depth = 10, loop 'ReuseLoop'
# WARNING: [HLS 200-871] Estimated clock period (15.492 ns) exceeds the target (target clock period: 5.000 ns, clock uncertainty: 1.350 ns, effective delay budget: 3.650 ns).
# Resolution: For help on HLS 200-871 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=200-871.html
# WARNING: [HLS 200-1016] The critical path in module 'dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s' consists of the following:
# 	'mux' operation ('tmp_s', firmware/nnet_utils/nnet_dense_resource.h:144) [164]  (2.328 ns)
# 	'add' operation ('add_ln144_2', firmware/nnet_utils/nnet_dense_resource.h:144) [167]  (1.825 ns)
# 	'icmp' operation ('icmp_ln144_2', firmware/nnet_utils/nnet_dense_resource.h:144) [168]  (1.870 ns)
# 	multiplexor before 'phi' operation ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [460]  (1.588 ns)
# 	'phi' operation ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [460]  (0.000 ns)
# 	multiplexor before 'phi' operation ('acc') with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [762]  (1.923 ns)
# 	'phi' operation ('acc') with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [762]  (0.000 ns)
# 	multiplexor before 'phi' operation ('acc') with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [1274]  (1.923 ns)
# 	'phi' operation ('acc') with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [1274]  (0.000 ns)
# 	multiplexor before 'phi' operation ('acc') with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [1376]  (1.707 ns)
# 	'phi' operation ('acc') with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [1376]  (0.000 ns)
# 	'phi' operation ('acc') with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [21]  (0.000 ns)
# 	'mux' operation ('tmp_s', firmware/nnet_utils/nnet_dense_resource.h:144) [164]  (2.328 ns)
#
# Resolution: For help on HLS 200-1016 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=200-1016.html
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111] Finished Scheduling: CPU user time: 963.92 seconds. CPU system time: 0.21 seconds. Elapsed time: 964.44 seconds; current allocated memory: 1.844 GB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111] Finished Binding: CPU user time: 6.03 seconds. CPU system time: 0.02 seconds. Elapsed time: 6.07 seconds; current allocated memory: 1.844 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'hard_sigmoid_ap_fixed_ap_ufixed_7_0_4_0_0_hard_sigmoid_config4_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining function 'hard_sigmoid<ap_fixed,ap_ufixed<7,0,4,0,0>,hard_sigmoid_config4>'.
# INFO: [HLS 200-1470] Pipelining result : Target II = NA, Final II = 1, Depth = 4, function 'hard_sigmoid<ap_fixed,ap_ufixed<7,0,4,0,0>,hard_sigmoid_config4>'
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111] Finished Scheduling: CPU user time: 6.2 seconds. CPU system time: 0.02 seconds. Elapsed time: 6.23 seconds; current allocated memory: 1.844 GB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111] Finished Binding: CPU user time: 0.28 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.28 seconds; current allocated memory: 1.844 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'dense_resource_rf_gt_nin_rem0_ap_ufixed_ap_fixed_22_9_5_3_0_config5_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining loop 'ReuseLoop'.
# INFO: [HLS 200-1470] Pipelining result : Target II = 1, Final II = 1, Depth = 6, loop 'ReuseLoop'
# WARNING: [HLS 200-871] Estimated clock period (11.179 ns) exceeds the target (target clock period: 5.000 ns, clock uncertainty: 1.350 ns, effective delay budget: 3.650 ns).
# Resolution: For help on HLS 200-871 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=200-871.html
# WARNING: [HLS 200-1016] The critical path in module 'dense_resource_rf_gt_nin_rem0_ap_ufixed_ap_fixed_22_9_5_3_0_config5_s' consists of the following:
# 	multiplexor before 'phi' operation ('acc') with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [544]  (1.588 ns)
# 	'phi' operation ('acc') with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [544]  (0.000 ns)
# 	multiplexor before 'phi' operation ('acc') with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [626]  (1.885 ns)
# 	'phi' operation ('acc') with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [626]  (0.000 ns)
# 	'phi' operation ('acc') with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [208]  (0.000 ns)
# 	'mux' operation ('tmp_s', firmware/nnet_utils/nnet_dense_resource.h:144) [451]  (2.423 ns)
# 	'add' operation ('add_ln144_1', firmware/nnet_utils/nnet_dense_resource.h:144) [454]  (1.825 ns)
# 	'icmp' operation ('icmp_ln144_1', firmware/nnet_utils/nnet_dense_resource.h:144) [455]  (1.870 ns)
# 	multiplexor before 'phi' operation ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [487]  (1.588 ns)
# 	'phi' operation ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) with incoming values : ('acc', firmware/nnet_utils/nnet_dense_resource.h:144) [487]  (0.000 ns)
#
# Resolution: For help on HLS 200-1016 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=200-1016.html
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111] Finished Scheduling: CPU user time: 1.83 seconds. CPU system time: 0.01 seconds. Elapsed time: 1.83 seconds; current allocated memory: 1.844 GB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111] Finished Binding: CPU user time: 0.12 seconds. CPU system time: 0 seconds. Elapsed time: 0.13 seconds; current allocated memory: 1.844 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'relu_ap_fixed_22_9_5_3_0_ap_ufixed_7_0_4_0_0_relu_config7_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining function 'relu<ap_fixed<22, 9, 5, 3, 0>, ap_ufixed<7, 0, 4, 0, 0>, relu_config7>'.
# INFO: [HLS 200-1470] Pipelining result : Target II = NA, Final II = 1, Depth = 2, function 'relu<ap_fixed<22, 9, 5, 3, 0>, ap_ufixed<7, 0, 4, 0, 0>, relu_config7>'
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111] Finished Scheduling: CPU user time: 0.47 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.47 seconds; current allocated memory: 1.844 GB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111] Finished Binding: CPU user time: 0.04 seconds. CPU system time: 0 seconds. Elapsed time: 0.04 seconds; current allocated memory: 1.844 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'dense_resource_rf_leq_nin_ap_ufixed_ap_fixed_18_9_5_3_0_config8_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining loop 'ReuseLoop'.
# INFO: [HLS 200-1470] Pipelining result : Target II = 1, Final II = 1, Depth = 8, loop 'ReuseLoop'
# WARNING: [HLS 200-871] Estimated clock period (4.842 ns) exceeds the target (target clock period: 5.000 ns, clock uncertainty: 1.350 ns, effective delay budget: 3.650 ns).
# Resolution: For help on HLS 200-871 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=200-871.html
# WARNING: [HLS 200-1016] The critical path in module 'dense_resource_rf_leq_nin_ap_ufixed_ap_fixed_18_9_5_3_0_config8_s' consists of the following:
# 	multiplexor before 'phi' operation ('w_index') with incoming values : ('w_index', firmware/nnet_utils/nnet_dense_resource.h:46) [34]  (1.588 ns)
# 	'phi' operation ('w_index') with incoming values : ('w_index', firmware/nnet_utils/nnet_dense_resource.h:46) [34]  (0.000 ns)
# 	'getelementptr' operation ('w8_addr', firmware/nnet_utils/nnet_dense_resource.h:59) [73]  (0.000 ns)
# 	'load' operation ('w', firmware/nnet_utils/nnet_dense_resource.h:59) on array 'w8' [74]  (3.254 ns)
#
# Resolution: For help on HLS 200-1016 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=200-1016.html
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111] Finished Scheduling: CPU user time: 0.18 seconds. CPU system time: 0 seconds. Elapsed time: 0.18 seconds; current allocated memory: 1.844 GB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111] Finished Binding: CPU user time: 0.08 seconds. CPU system time: 0 seconds. Elapsed time: 0.08 seconds; current allocated memory: 1.844 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'sigmoid_ap_fixed_18_9_5_3_0_ap_fixed_6_3_4_0_0_sigmoid_config10_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining function 'sigmoid<ap_fixed<18, 9, 5, 3, 0>, ap_fixed<6, 3, 4, 0, 0>, sigmoid_config10>'.
# INFO: [HLS 200-1470] Pipelining result : Target II = NA, Final II = 1, Depth = 5, function 'sigmoid<ap_fixed<18, 9, 5, 3, 0>, ap_fixed<6, 3, 4, 0, 0>, sigmoid_config10>'
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111] Finished Scheduling: CPU user time: 0.08 seconds. CPU system time: 0 seconds. Elapsed time: 0.08 seconds; current allocated memory: 1.844 GB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111] Finished Binding: CPU user time: 0.05 seconds. CPU system time: 0 seconds. Elapsed time: 0.05 seconds; current allocated memory: 1.844 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'myproject'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# WARNING: [HLS 200-871] Estimated clock period (16.340 ns) exceeds the target (target clock period: 5.000 ns, clock uncertainty: 1.350 ns, effective delay budget: 3.650 ns).
# Resolution: For help on HLS 200-871 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=200-871.html
# WARNING: [HLS 200-1016] The critical path in module 'myproject' consists of the following:
# 	'call' operation ('call_ret1', firmware/nnet_utils/nnet_dense.h:76->firmware/nnet_utils/nnet_dense.h:45->firmware/myproject.cpp:38) to 'dense_resource_rf_gt_nin_rem0<ap_fixed,ap_fixed<21,12,5,3,0>,config2>' [18]  (16.340 ns)
#
# Resolution: For help on HLS 200-1016 see www.xilinx.com/cgi-bin/docs/rdoc?v=2023.1;t=hls+guidance;d=200-1016.html
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111] Finished Scheduling: CPU user time: 0.15 seconds. CPU system time: 0 seconds. Elapsed time: 0.16 seconds; current allocated memory: 1.844 GB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111] Finished Binding: CPU user time: 0.19 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.18 seconds; current allocated memory: 1.844 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SYN 201-210] Renamed object name 'dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s_outidx_1_ROM_AUTO_1R' to 'dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s_outidx_bkb' due to the length limit 80
# INFO: [SYN 201-210] Renamed object name 'dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s_w2_ROM_NP_BRAM_1R' to 'dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s_w2_ROM_cud' due to the length limit 80
# INFO: [HLS 200-1030] Apply Unified Pipeline Control on module 'dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s' pipeline 'ReuseLoop' pipeline type 'rewind pipeline'
# INFO: [HLS 200-1552] Enabling free running pipeline (frp) architecture on pipeline 'ReuseLoop' in module 'dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s'. Estimated max control fanout for pipeline is 21351.
# INFO: [RTGEN 206-100] Generating core module 'lshr_600ns_10ns_600_7_1': 1 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_6s_6s_12_3_1': 1 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mux_100_7_6_2_1': 1 instance(s).
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s'.
# INFO: [RTMG 210-279] Implementing memory 'myproject_dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s_outidx_bkb' using auto ROMs.
# INFO: [RTMG 210-279] Implementing memory 'myproject_dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s_w2_ROM_cud' using block ROMs.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 13.84 seconds. CPU system time: 0 seconds. Elapsed time: 13.87 seconds; current allocated memory: 1.844 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'hard_sigmoid_ap_fixed_ap_ufixed_7_0_4_0_0_hard_sigmoid_config4_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-1030] Apply Unified Pipeline Control on module 'hard_sigmoid_ap_fixed_ap_ufixed_7_0_4_0_0_hard_sigmoid_config4_s' pipeline 'hard_sigmoid<ap_fixed,ap_ufixed<7,0,4,0,0>,hard_sigmoid_config4>' pipeline type 'function pipeline'
# INFO: [HLS 200-1552] Enabling free running pipeline (frp) architecture on pipeline 'hard_sigmoid<ap_fixed,ap_ufixed<7,0,4,0,0>,hard_sigmoid_config4>' in module 'hard_sigmoid_ap_fixed_ap_ufixed_7_0_4_0_0_hard_sigmoid_config4_s'. Estimated max control fanout for pipeline is 8000.
# INFO: [RTGEN 206-100] Finished creating RTL model for 'hard_sigmoid_ap_fixed_ap_ufixed_7_0_4_0_0_hard_sigmoid_config4_s'.
# ...
# INFO: [RTMG 210-285] Implementing FIFO 'layer2_out_91_U(myproject_fifo_w12_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer2_out_92_U(myproject_fifo_w12_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer2_out_93_U(myproject_fifo_w12_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer2_out_94_U(myproject_fifo_w12_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer2_out_95_U(myproject_fifo_w12_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer2_out_96_U(myproject_fifo_w12_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer2_out_97_U(myproject_fifo_w12_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer2_out_98_U(myproject_fifo_w12_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer2_out_99_U(myproject_fifo_w12_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_1_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_2_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_3_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_4_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_5_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_6_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_7_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_8_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_9_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_10_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_11_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_12_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_13_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_14_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_15_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_16_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_17_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_18_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_19_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_20_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_21_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_22_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_23_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_24_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_25_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_26_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_27_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_28_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_29_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_30_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_31_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_32_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_33_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_34_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_35_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_36_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_37_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_38_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_39_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_40_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_41_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_42_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_43_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_44_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_45_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_46_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_47_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_48_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_49_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_50_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_51_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_52_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_53_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_54_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_55_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_56_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_57_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_58_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_59_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_60_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_61_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_62_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_63_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_64_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_65_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_66_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_67_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_68_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_69_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_70_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_71_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_72_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_73_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_74_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_75_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_76_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_77_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_78_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_79_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_80_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_81_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_82_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_83_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_84_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_85_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_86_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_87_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_88_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_89_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_90_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_91_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_92_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_93_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_94_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_95_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_96_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_97_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_98_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer4_out_99_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_U(myproject_fifo_w16_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_1_U(myproject_fifo_w16_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_2_U(myproject_fifo_w16_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_3_U(myproject_fifo_w16_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_4_U(myproject_fifo_w16_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_5_U(myproject_fifo_w16_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_6_U(myproject_fifo_w16_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_7_U(myproject_fifo_w16_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_8_U(myproject_fifo_w16_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_9_U(myproject_fifo_w16_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_10_U(myproject_fifo_w16_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_11_U(myproject_fifo_w16_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_12_U(myproject_fifo_w16_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_13_U(myproject_fifo_w16_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_1_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_2_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_3_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_4_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_5_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_6_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_7_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_8_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_9_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_10_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_11_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_12_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_13_U(myproject_fifo_w7_d2_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_U(myproject_fifo_w12_d2_S)' using Shift Registers.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.72 seconds. CPU system time: 0.05 seconds. Elapsed time: 0.77 seconds; current allocated memory: 1.844 GB.
# INFO: [RTMG 210-286] Generating pipelined shifter : 'myproject_lshr_600ns_10ns_600_7_1'
# INFO: [RTMG 210-288] Generating pipelined multiplexer : 'myproject_mux_100_7_6_2_1'
# INFO: [RTMG 210-288] Generating pipelined multiplexer : 'myproject_mux_100_7_7_2_1'
# INFO: [HLS 200-111] Finished Generating all RTL models: CPU user time: 11.68 seconds. CPU system time: 0.06 seconds. Elapsed time: 11.74 seconds; current allocated memory: 1.855 GB.
# INFO: [HLS 200-111] Finished Updating report files: CPU user time: 0.57 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.6 seconds; current allocated memory: 1.871 GB.
# INFO: [VHDL 208-304] Generating VHDL RTL for myproject.
# INFO: [VLOG 209-307] Generating Verilog RTL for myproject.
# INFO: [HLS 200-790] **** Loop Constraint Status: All loop constraints were satisfied.
# INFO: [HLS 200-789] **** Estimated Fmax: 61.20 MHz
# INFO: [HLS 200-111] Finished Command csynth_design CPU user time: 1039.25 seconds. CPU system time: 2.28 seconds. Elapsed time: 1044.2 seconds; current allocated memory: 826.758 MB.
# ***** C/RTL SYNTHESIS COMPLETED IN 0h17m24s *****
# INFO: [HLS 200-112] Total CPU user time: 1041.82 seconds. Total CPU system time: 2.79 seconds. Total elapsed time: 1047.15 seconds; peak allocated memory: 1.872 GB.
# INFO: [Common 17-206] Exiting vitis_hls at Thu May 15 21:16:05 2025...
# Vivado synthesis report not found.
# Cosim report not found.
# Timing report not found.

# %%
if synth_hls:
    hls4ml.report.read_vivado_report(name + '/hls4ml_prj')
# Out:
# Found 1 solution(s) in mza_try16/hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vitis HLS Report for 'myproject'
# ================================================================
# * Date:           Thu May 15 21:15:55 2025
#
# * Version:        2023.1 (Build 3854077 on May  4 2023)
# * Project:        myproject_prj
# * Solution:       solution1 (Vivado IP Flow Target)
# * Product family: zynq
# * Target device:  xc7z020-clg400-1
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+-----------+------------+
#     |  Clock |  Target | Estimated | Uncertainty|
#     +--------+---------+-----------+------------+
#     |ap_clk  |  5.00 ns|  16.340 ns|     1.35 ns|
#     +--------+---------+-----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+----------+----------+-------+-------+----------+
#     |  Latency (cycles) |  Latency (absolute) |    Interval   | Pipeline |
#     |   min   |   max   |    min   |    max   |  min  |  max  |   Type   |
#     +---------+---------+----------+----------+-------+-------+----------+
#     |    11440|    11443|  0.187 ms|  0.187 ms|  10000|  10000|  dataflow|
#     +---------+---------+----------+----------+-------+-------+----------+
#
#     + Detail:
#         * Instance:
#         +------------------------------------------------------------------------+-----------------------------------------------------------------------+---------+---------+-----------+-----------+-------+-------+------------------------------------------+
#         |                                                                        |                                                                       |  Latency (cycles) |   Latency (absolute)  |    Interval   |                 Pipeline                 |
#         |                                Instance                                |                                 Module                                |   min   |   max   |    min    |    max    |  min  |  max  |                   Type                   |
#         +------------------------------------------------------------------------+-----------------------------------------------------------------------+---------+---------+-----------+-----------+-------+-------+------------------------------------------+
#         |dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_U0  |dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s  |    10008|    10009|   0.155 ms|   0.155 ms|  10000|  10000|  loop rewind stp(delay=0 clock cycles(s))|
#         |hard_sigmoid_ap_fixed_ap_ufixed_7_0_4_0_0_hard_sigmoid_config4_U0       |hard_sigmoid_ap_fixed_ap_ufixed_7_0_4_0_0_hard_sigmoid_config4_s       |        3|        3|  15.000 ns|  15.000 ns|      1|      1|                                       yes|
#         |dense_resource_rf_gt_nin_rem0_ap_ufixed_ap_fixed_22_9_5_3_0_config5_U0  |dense_resource_rf_gt_nin_rem0_ap_ufixed_ap_fixed_22_9_5_3_0_config5_s  |     1404|     1405|  15.695 us|  15.706 us|   1400|   1400|  loop rewind stp(delay=0 clock cycles(s))|
#         |relu_ap_fixed_22_9_5_3_0_ap_ufixed_7_0_4_0_0_relu_config7_U0            |relu_ap_fixed_22_9_5_3_0_ap_ufixed_7_0_4_0_0_relu_config7_s            |        1|        1|   5.000 ns|   5.000 ns|      1|      1|                                       yes|
#         |dense_resource_rf_leq_nin_ap_ufixed_ap_fixed_18_9_5_3_0_config8_U0      |dense_resource_rf_leq_nin_ap_ufixed_ap_fixed_18_9_5_3_0_config8_s      |       20|       21|   0.100 us|   0.105 us|     14|     14|  loop rewind stp(delay=0 clock cycles(s))|
#         |sigmoid_ap_fixed_18_9_5_3_0_ap_fixed_6_3_4_0_0_sigmoid_config10_U0      |sigmoid_ap_fixed_18_9_5_3_0_ap_fixed_6_3_4_0_0_sigmoid_config10_s      |        4|        4|  20.000 ns|  20.000 ns|      1|      1|                                       yes|
#         +------------------------------------------------------------------------+-----------------------------------------------------------------------+---------+---------+-----------+-----------+-------+-------+------------------------------------------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +-----------------+---------+-----+--------+-------+-----+
# |       Name      | BRAM_18K| DSP |   FF   |  LUT  | URAM|
# +-----------------+---------+-----+--------+-------+-----+
# |DSP              |        -|    -|       -|      -|    -|
# |Expression       |        -|    -|       0|    930|    -|
# |FIFO             |        -|    -|   22671|  15572|    -|
# |Instance         |       17|    3|   18044|  34912|    -|
# |Memory           |        -|    -|       -|      -|    -|
# |Multiplexer      |        -|    -|       -|   2052|    -|
# |Register         |        -|    -|     228|      -|    -|
# +-----------------+---------+-----+--------+-------+-----+
# |Total            |       17|    3|   40943|  53466|    0|
# +-----------------+---------+-----+--------+-------+-----+
# |Available        |      280|  220|  106400|  53200|    0|
# +-----------------+---------+-----+--------+-------+-----+
# |Utilization (%)  |        6|    1|      38|    100|    0|
# +-----------------+---------+-----+--------+-------+-----+
#
# + Detail:
#     * Instance:
#     +------------------------------------------------------------------------+-----------------------------------------------------------------------+---------+----+------+-------+-----+
#     |                                Instance                                |                                 Module                                | BRAM_18K| DSP|  FF  |  LUT  | URAM|
#     +------------------------------------------------------------------------+-----------------------------------------------------------------------+---------+----+------+-------+-----+
#     |dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_U0  |dense_resource_rf_gt_nin_rem0_ap_fixed_ap_fixed_21_12_5_3_0_config2_s  |       13|   1|  8255|  15078|    0|
#     |dense_resource_rf_gt_nin_rem0_ap_ufixed_ap_fixed_22_9_5_3_0_config5_U0  |dense_resource_rf_gt_nin_rem0_ap_ufixed_ap_fixed_22_9_5_3_0_config5_s  |        2|   1|  3531|   5215|    0|
#     |dense_resource_rf_leq_nin_ap_ufixed_ap_fixed_18_9_5_3_0_config8_U0      |dense_resource_rf_leq_nin_ap_ufixed_ap_fixed_18_9_5_3_0_config8_s      |        1|   1|   251|    526|    0|
#     |hard_sigmoid_ap_fixed_ap_ufixed_7_0_4_0_0_hard_sigmoid_config4_U0       |hard_sigmoid_ap_fixed_ap_ufixed_7_0_4_0_0_hard_sigmoid_config4_s       |        0|   0|  5602|  12624|    0|
#     |relu_ap_fixed_22_9_5_3_0_ap_ufixed_7_0_4_0_0_relu_config7_U0            |relu_ap_fixed_22_9_5_3_0_ap_ufixed_7_0_4_0_0_relu_config7_s            |        0|   0|   353|   1329|    0|
#     |sigmoid_ap_fixed_18_9_5_3_0_ap_fixed_6_3_4_0_0_sigmoid_config10_U0      |sigmoid_ap_fixed_18_9_5_3_0_ap_fixed_6_3_4_0_0_sigmoid_config10_s      |        1|   0|    52|    140|    0|
#     +------------------------------------------------------------------------+-----------------------------------------------------------------------+---------+----+------+-------+-----+
#     |Total                                                                   |                                                                       |       17|   3| 18044|  34912|    0|
#     +------------------------------------------------------------------------+-----------------------------------------------------------------------+---------+----+------+-------+-----+
#
#     * DSP:
#     N/A
#
#     * Memory:
#     N/A
#
#     * FIFO:
#     +-----------------+---------+-----+----+-----+------+-----+---------+
#     |       Name      | BRAM_18K|  FF | LUT| URAM| Depth| Bits| Size:D*B|
#     +-----------------+---------+-----+----+-----+------+-----+---------+
#     |layer2_out_10_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_11_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_12_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_13_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_14_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_15_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_16_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_17_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_18_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_19_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_1_U   |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_20_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_21_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_22_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_23_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_24_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_25_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_26_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_27_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_28_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_29_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_2_U   |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_30_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_31_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_32_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_33_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_34_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_35_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_36_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_37_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_38_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_39_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_3_U   |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_40_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_41_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_42_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_43_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_44_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_45_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_46_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_47_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_48_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_49_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_4_U   |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_50_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_51_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_52_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_53_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_54_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_55_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_56_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_57_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_58_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_59_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_5_U   |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_60_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_61_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_62_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_63_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_64_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_65_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_66_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_67_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_68_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_69_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_6_U   |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_70_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_71_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_72_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_73_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_74_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_75_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_76_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_77_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_78_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_79_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_7_U   |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_80_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_81_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_82_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_83_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_84_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_85_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_86_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_87_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_88_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_89_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_8_U   |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_90_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_91_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_92_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_93_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_94_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_95_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_96_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_97_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_98_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_99_U  |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_9_U   |        0|   99|   0|    -|     2|   12|       24|
#     |layer2_out_U     |        0|   99|   0|    -|     2|   12|       24|
#     |layer4_out_10_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_11_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_12_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_13_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_14_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_15_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_16_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_17_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_18_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_19_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_1_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_20_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_21_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_22_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_23_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_24_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_25_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_26_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_27_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_28_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_29_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_2_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_30_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_31_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_32_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_33_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_34_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_35_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_36_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_37_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_38_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_39_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_3_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_40_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_41_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_42_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_43_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_44_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_45_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_46_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_47_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_48_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_49_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_4_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_50_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_51_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_52_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_53_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_54_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_55_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_56_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_57_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_58_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_59_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_5_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_60_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_61_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_62_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_63_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_64_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_65_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_66_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_67_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_68_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_69_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_6_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_70_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_71_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_72_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_73_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_74_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_75_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_76_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_77_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_78_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_79_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_7_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_80_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_81_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_82_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_83_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_84_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_85_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_86_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_87_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_88_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_89_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_8_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_90_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_91_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_92_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_93_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_94_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_95_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_96_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_97_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_98_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_99_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_9_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer4_out_U     |        0|   99|   0|    -|     2|    7|       14|
#     |layer5_out_10_U  |        0|   99|   0|    -|     2|   16|       32|
#     |layer5_out_11_U  |        0|   99|   0|    -|     2|   16|       32|
#     |layer5_out_12_U  |        0|   99|   0|    -|     2|   16|       32|
#     |layer5_out_13_U  |        0|   99|   0|    -|     2|   16|       32|
#     |layer5_out_1_U   |        0|   99|   0|    -|     2|   16|       32|
#     |layer5_out_2_U   |        0|   99|   0|    -|     2|   16|       32|
#     |layer5_out_3_U   |        0|   99|   0|    -|     2|   16|       32|
#     |layer5_out_4_U   |        0|   99|   0|    -|     2|   16|       32|
#     |layer5_out_5_U   |        0|   99|   0|    -|     2|   16|       32|
#     |layer5_out_6_U   |        0|   99|   0|    -|     2|   16|       32|
#     |layer5_out_7_U   |        0|   99|   0|    -|     2|   16|       32|
#     |layer5_out_8_U   |        0|   99|   0|    -|     2|   16|       32|
#     |layer5_out_9_U   |        0|   99|   0|    -|     2|   16|       32|
#     |layer5_out_U     |        0|   99|   0|    -|     2|   16|       32|
#     |layer7_out_10_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer7_out_11_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer7_out_12_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer7_out_13_U  |        0|   99|   0|    -|     2|    7|       14|
#     |layer7_out_1_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer7_out_2_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer7_out_3_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer7_out_4_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer7_out_5_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer7_out_6_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer7_out_7_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer7_out_8_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer7_out_9_U   |        0|   99|   0|    -|     2|    7|       14|
#     |layer7_out_U     |        0|   99|   0|    -|     2|    7|       14|
#     |layer8_out_U     |        0|   99|   0|    -|     2|   12|       24|
#     +-----------------+---------+-----+----+-----+------+-----+---------+
#     |Total            |        0|22671|   0|    0|   458| 2234|     4468|
#     +-----------------+---------+-----+----+-----+------+-----+---------+
#
#     * Expression:
#     +------------------------------------------------------------------------------------+----------+----+---+----+------------+------------+
#     |                                    Variable Name                                   | Operation| DSP| FF| LUT| Bitwidth P0| Bitwidth P1|
#     +------------------------------------------------------------------------------------+----------+----+---+----+------------+------------+
#     |ap_channel_done_layer2_out                                                          |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_1                                                        |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_10                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_11                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_12                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_13                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_14                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_15                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_16                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_17                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_18                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_19                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_2                                                        |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_20                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_21                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_22                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_23                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_24                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_25                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_26                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_27                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_28                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_29                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_3                                                        |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_30                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_31                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_32                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_33                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_34                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_35                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_36                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_37                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_38                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_39                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_4                                                        |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_40                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_41                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_42                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_43                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_44                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_45                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_46                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_47                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_48                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_49                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_5                                                        |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_50                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_51                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_52                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_53                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_54                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_55                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_56                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_57                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_58                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_59                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_6                                                        |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_60                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_61                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_62                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_63                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_64                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_65                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_66                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_67                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_68                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_69                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_7                                                        |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_70                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_71                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_72                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_73                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_74                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_75                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_76                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_77                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_78                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_79                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_8                                                        |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_80                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_81                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_82                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_83                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_84                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_85                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_86                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_87                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_88                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_89                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_9                                                        |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_90                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_91                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_92                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_93                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_94                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_95                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_96                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_97                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_98                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer2_out_99                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out                                                          |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_1                                                        |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_10                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_11                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_12                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_13                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_14                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_15                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_16                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_17                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_18                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_19                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_2                                                        |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_20                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_21                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_22                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_23                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_24                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_25                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_26                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_27                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_28                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_29                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_3                                                        |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_30                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_31                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_32                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_33                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_34                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_35                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_36                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_37                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_38                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_39                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_4                                                        |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_40                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_41                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_42                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_43                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_44                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_45                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_46                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_47                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_48                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_49                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_5                                                        |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_50                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_51                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_52                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_53                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_54                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_55                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_56                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_57                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_58                                                       |       and|   0|  0|   2|           1|           1|
#     |ap_channel_done_layer4_out_59                                                       |       and|   0|  0|   2|           1|           1|
# ...
#     |ap_sync_reg_channel_write_layer2_out_43  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_44  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_45  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_46  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_47  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_48  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_49  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_5   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_50  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_51  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_52  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_53  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_54  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_55  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_56  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_57  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_58  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_59  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_6   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_60  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_61  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_62  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_63  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_64  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_65  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_66  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_67  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_68  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_69  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_7   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_70  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_71  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_72  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_73  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_74  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_75  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_76  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_77  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_78  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_79  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_8   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_80  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_81  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_82  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_83  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_84  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_85  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_86  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_87  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_88  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_89  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_9   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_90  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_91  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_92  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_93  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_94  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_95  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_96  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_97  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_98  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer2_out_99  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out     |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_1   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_10  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_11  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_12  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_13  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_14  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_15  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_16  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_17  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_18  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_19  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_2   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_20  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_21  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_22  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_23  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_24  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_25  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_26  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_27  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_28  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_29  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_3   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_30  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_31  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_32  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_33  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_34  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_35  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_36  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_37  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_38  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_39  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_4   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_40  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_41  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_42  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_43  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_44  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_45  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_46  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_47  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_48  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_49  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_5   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_50  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_51  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_52  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_53  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_54  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_55  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_56  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_57  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_58  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_59  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_6   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_60  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_61  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_62  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_63  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_64  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_65  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_66  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_67  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_68  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_69  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_7   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_70  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_71  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_72  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_73  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_74  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_75  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_76  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_77  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_78  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_79  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_8   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_80  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_81  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_82  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_83  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_84  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_85  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_86  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_87  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_88  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_89  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_9   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_90  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_91  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_92  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_93  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_94  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_95  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_96  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_97  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_98  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer4_out_99  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer5_out     |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer5_out_1   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer5_out_10  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer5_out_11  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer5_out_12  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer5_out_13  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer5_out_2   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer5_out_3   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer5_out_4   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer5_out_5   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer5_out_6   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer5_out_7   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer5_out_8   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer5_out_9   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer7_out     |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer7_out_1   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer7_out_10  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer7_out_11  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer7_out_12  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer7_out_13  |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer7_out_2   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer7_out_3   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer7_out_4   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer7_out_5   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer7_out_6   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer7_out_7   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer7_out_8   |  1|   0|    1|          0|
#     |ap_sync_reg_channel_write_layer7_out_9   |  1|   0|    1|          0|
#     +-----------------------------------------+---+----+-----+-----------+
#     |Total                                    |228|   0|  228|          0|
#     +-----------------------------------------+---+----+-----+-----------+
#
#
#
# ================================================================
# == Interface
# ================================================================
# * Summary:
# +---------------------------+-----+-----+------------+--------------------+--------------+
# |         RTL Ports         | Dir | Bits|  Protocol  |    Source Object   |    C Type    |
# +---------------------------+-----+-----+------------+--------------------+--------------+
# |input_qdense_input         |   in|  600|      ap_vld|  input_qdense_input|       pointer|
# |input_qdense_input_ap_vld  |   in|    1|      ap_vld|  input_qdense_input|       pointer|
# |layer10_out                |  out|    6|      ap_vld|         layer10_out|       pointer|
# |layer10_out_ap_vld         |  out|    1|      ap_vld|         layer10_out|       pointer|
# |ap_clk                     |   in|    1|  ap_ctrl_hs|           myproject|  return value|
# |ap_rst                     |   in|    1|  ap_ctrl_hs|           myproject|  return value|
# |ap_start                   |   in|    1|  ap_ctrl_hs|           myproject|  return value|
# |ap_done                    |  out|    1|  ap_ctrl_hs|           myproject|  return value|
# |ap_ready                   |  out|    1|  ap_ctrl_hs|           myproject|  return value|
# |ap_idle                    |  out|    1|  ap_ctrl_hs|           myproject|  return value|
# +---------------------------+-----+-----+------------+--------------------+--------------+
#
# Co-simulation report not found.
